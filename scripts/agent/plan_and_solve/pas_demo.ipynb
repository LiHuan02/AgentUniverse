# %%
import os
import sys
BASE_DIR = os.path.abspath(os.path.join(os.getcwd(), '../../..'))
if BASE_DIR not in sys.path:
    sys.path.insert(0, BASE_DIR)

from plan_and_aolve_agent import PlanAndSolveAgent
from scripts.base.my_llm import MyLLM

llm = MyLLM()
pas_agent = PlanAndSolveAgent(llm=llm)

question = """
背景：
你是班级生活委员，要组织一次周末春游。全班 40 人，每人预算 50 元（总预算 2000 元）。需要完成以下任务：
- 租一辆大巴（含司机），往返费用 800 元。
- 购买零食和饮料，每份套餐（1 人量）12 元。
- 准备 3 种集体游戏道具，每种道具单价分别为 25 元、18 元、30 元，每种买 2 套。
- 剩余的钱全部用于购买纪念品（单价 8 元，最多每人 1 份）。
问题：
- 是否够买所有必须品（大巴+零食+游戏道具）？
- 如果够，剩余多少钱？最多可以买多少份纪念品？实际每人能否都得到一份？
"""

pas_agent.run(question=question)
# Out:
# --- 开始处理问题 ---
# 问题:
# 背景：
# 你是班级生活委员，要组织一次周末春游。全班 40 人，每人预算 50 元（总预算 2000 元）。需要完成以下任务：
# - 租一辆大巴（含司机），往返费用 800 元。
# - 购买零食和饮料，每份套餐（1 人量）12 元。
# - 准备 3 种集体游戏道具，每种道具单价分别为 25 元、18 元、30 元，每种买 2 套。
# - 剩余的钱全部用于购买纪念品（单价 8 元，最多每人 1 份）。
# 问题：
# - 是否够买所有必须品（大巴+零食+游戏道具）？
# - 如果够，剩余多少钱？最多可以买多少份纪念品？实际每人能否都得到一份？
#
# --- 正在生成计划 ---
# 🧠 正在调用 deepseek-v4-pro 模型...
# ```python
# ["明确总预算金额：2000元。", "计算租用大巴的固定费用：800元。", "计算全班40人每人一份零食和饮料的总费用：40 × 12元。", "计算三种集体游戏道具的总费用：(25元 + 18元 + 30元) × 2套。", "将所有必需品费用相加：大巴费 + 零食饮料费 + 游戏道具费，得到必需品总费用。", "比较必需品总费用是否小于或等于总预算2000元，判断资金是否足够购买所有必需品。", "若资金足够，计算剩余金额：2000元 - 必需品总费用。", "用剩余金额除以纪念品单价8元，并向下取整，得出按金额可购买的最大份数。", "将按金额可购买的最大份数与全班人数40人比较，取较小值（因为每人最多一份），得到实际可购买的纪念品份数。", "对比实际可购买纪念品份数与40，判断是否每人能获得一份纪念品，并总结剩余金额和纪念品数量。"]
# ```
# ✅ 计划已生成:
# ```python
# ...
